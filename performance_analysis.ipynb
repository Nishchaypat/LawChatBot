# %%
import pandas as pd

df=pd.read_csv(r"cleaned_evaluation_results.csv")
print(df.columns)
print(df.shape)
# Out:
# Index(['query', 'gemini_weight', 'voyage_weight', 'indices', 'response',
#        'time', 'indices_parsed', 'gemini_top_values', 'gemini_top_avg',
#        'query_length', 'response_length', 'weight_ratio', 'time_winsorized'],
#       dtype='object')
# (2001, 13)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(8, 5))
plt.hist(df['time_winsorized'], bins='auto', color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')
plt.title('Histogram of Time to Generate Answer')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df['response'].unique()
# Out:
# array(["I am unable to answer the question. The text does not include any information related to *United States v. Morris*, 928 F.2d 504 (2d Cir. 1991), jurisprudence interpreting the 'protected computer' definition under § 1030(e)(2), the standard of appellate review, the *de minimis non curat lex* doctrine, the Sixth Amendment's guarantee of a jury trial, or *Apprendi v. New Jersey*, 530 U.S. 466 (2000).",
#        'Under 18 U.S.C. § 1030(a)(5), several actions can trigger criminal liability concerning damage to a protected computer. These include:\n\n*   Intentionally causing damage without authorization to a protected computer by knowingly causing the transmission of a program, information, code, or command (Voyage model).\n*   Intentionally accessing a protected computer without authorization, recklessly causing damage as a result of such conduct (Voyage model).\n*   Intentionally accessing a protected computer without authorization, causing damage and loss as a result of such conduct (Voyage model).\n\nThe term "damage" under 18 U.S.C. § 1030(e)(8) means any impairment to the integrity or availability of data, a program, a system, or information (Voyage model).\n\nRegarding the "loss" provision under 18 U.S.C. § 1030(e)(11), "loss" means any reasonable cost to any victim, including the cost of responding to an offense, conducting a damage assessment, and restoring the data, program, system, or information to its condition prior to the offense, and any revenue lost, cost incurred, or other consequential damages incurred because of interruption of service (Voyage model).\n\nThe provided legal documents do not explicitly detail the specific evidence required to establish the "reasonable cost" of responding to an offense, conducting a damage assessment, and restoring data, as well as any consequential damages resulting from service interruption.\n\nRegarding defenses available to a defendant charged with violating 18 U.S.C. § 1030(a)(5), the document says that 18 U.S.C. § 1030(f) says that the section does not prohibit any lawfully authorized investigative, protective, or intelligence activity of a law enforcement agency of the United States, a State, or a political subdivision of a State, or of an intelligence agency of the United States (Voyage model).',
#        'Under 18 U.S.C. § 1030, the Computer Fraud and Abuse Act (CFAA), "damage" is defined as "any impairment to the integrity or availability of data, a program, a system, or information" (Voyage model).\n\nRegarding financial loss, the term "loss" means any reasonable cost to any victim, including the cost of responding to an offense, conducting a damage assessment, and restoring the data, program, system, or information to its condition prior to the offense, and any revenue lost, cost incurred, or other consequential damages incurred because of interruption of service (Voyage model).\n\nTo press charges the offended party would need to show, the value of loss to one or more persons during any 1-year period (and, for purposes of an investigation, prosecution, or other proceeding brought by the United States only, loss resulting from a related course of conduct affecting 1 or more other protected computers) aggregating at least $5,000 in value (Voyage model).',
#        ...,
#        'Based on the provided legal documents, the following points address the question of intent in piracy convictions under 18 U.S.C. § 1651 et seq.:\n\n*   **General Definition of Piracy:** 18 U.S.C. § 1651 states, "Whoever, on the high seas, commits the crime of piracy as defined by the law of nations, and is afterwards brought into or found in the United States, shall be imprisoned for life." The definition of piracy relies on the "law of nations," which is not further defined in the provided context (Voyage model).\n*   **Specific Intent Crimes:** Several sections outline specific actions and required intents:\n    *   **Attack to plunder vessel:** 18 U.S.C. § 1659 states that attacking a vessel with the intent to plunder is punishable by a fine or imprisonment (Voyage model).\n    *   **Plunder of distressed vessel:** 18 U.S.C. § 1658(a) addresses plundering a distressed vessel (Voyage model).\n    *   **Destruction of vessel by nonowner:** According to 18 U.S.C. § 2273, a non-owner who "willfully and corruptly casts away or otherwise destroys any vessel of the United States to which he belongs, or willfully attempts the destruction thereof, shall be imprisoned not more than ten years" (Gemini model, Voyage model).\n    *   **Firing or tampering with vessel:** According to 18 U.S.C. § 2275, whoever sets fire to any vessel, tampers with the motive power, places bombs or explosives with intent to injure or endanger the safety of the vessel shall be fined or imprisoned (Gemini model).\n*   **Corruption of Seamen:** 18 U.S.C. § 1657 addresses attempts to corrupt seamen to "yield up or to run away with any vessel" or to "turn pirate" (Voyage model).\n*   **Submersible Vessels:** According to §2285, operating a submersible vessel or semi-submersible vessel without nationality with the intent to evade detection is a crime. (Gemini model).\n*   **Evidence of Intent to Evade Detection:** §2285(b) states that the presence of any of the indicia described in paragraph (1)(A), (E), (F), or (G), or in paragraph (4), (5), or (6), of section 70507(b) of title 46 may be considered, in the totality of the circumstances, to be prima facie evidence of intent to evade detection (Gemini model).\n\nThe documents do not provide specific details on how the government proves intent beyond a reasonable doubt or how to overcome a claim of right defense in piracy cases.',
#        'Based on the provided U.S. Code sections, the elements the government needs to prove to establish piracy, as opposed to legitimate salvage or self-defense, are not explicitly detailed. However, the documents do provide insight into actions that constitute piracy:\n\n*   **Piracy under the law of nations:** Committing the crime of piracy as defined by the law of nations on the high seas (18 U.S.C. § 1651).\n*   **Citizens as pirates:** A U.S. citizen committing murder, robbery, or any act of hostility against the United States, or its citizens, on the high seas, under color of any commission from any foreign power (18 U.S.C. § 1652).\n*   **Aliens as pirates:** A citizen or subject of a foreign state, found on the sea making war upon the United States, or cruising against its vessels and property, contrary to any treaty between the U.S. and their state, when such acts are declared piracy by treaty (18 U.S.C. § 1653).\n*   **Attack to plunder vessel:** Attacking or setting upon any vessel belonging to another, with an intent unlawfully to plunder the same, or to despoil any owner thereof (18 U.S.C. § 1659).\n*   **Robbery ashore:** Being engaged in any piratical cruise or enterprise, or being of the crew of any piratical vessel, lands from such vessel and commits robbery on shore (18 U.S.C. § 1661).\n\nTo prove piracy, the government would likely need to demonstrate intent to commit these specific acts for personal gain, as opposed to acting in self-defense or engaging in legitimate salvage operations. The documents do not specify what kind of evidence would be required.',
#        "I am unable to answer your question. The document does not contain the answer to how a court decides if someone is a pirate or the kind of proof needed to show the person really meant to steal and attack, and wasn't just trying to help."],
#       dtype=object)

# %%
filtered_df = df[df['response'].str.contains("I am unable to answer your question.", na=False)]

# Display the result
print(filtered_df)
# Out:
#                                                   query  gemini_weight  \
# 4     Given 18 U.S.C. § 1531, specifically subsectio...       0.050000
# 28    Given the enactment of Chapter 50 of Title 18,...       0.050000
# 80    Given the legislative history detailed within ...       0.050000
# 144   Pursuant to 18 U.S.C. § 3682, and considering ...       0.050000
# 160   Given the enactment of 18 U.S.C. § 3297, which...       0.050000
# 244   Pursuant to 18 U.S.C. § 1709, which proscribes...       0.050000
# 289   Under 18 U.S.C. § 343, what evidence is requir...       0.400000
# 372   Given 18 U.S.C. § 287, regarding false, fictit...       0.050000
# 396   Pursuant to 18 U.S.C. § 1366(b), and consideri...       0.050000
# 404   Given the statutory language of 18 U.S.C. § 31...       0.050000
# 408   Given 18 U.S.C. § 1752(a)(5), concerning the o...       0.050000
# 448   Under 18 U.S.C. § 2119, and considering the me...       0.050000
# 460   Given the expansive definition of "agency of t...       0.050000
# 485   Following the 1997 amendments by Pub. L. 105-1...       0.400000
# 620   Given 18 U.S.C. § 913, predicated on *mens rea...       0.400000
# 644   Given 18 U.S.C. § 653, and considering the 199...       0.050000
# 648   Considering the amendments to 18 U.S.C. § 3013...       0.050000
# 678   This law requires federal prisons for women to...       0.400000
# 724   Given the 2017 amendment to 18 U.S.C. § 2325 e...       0.050000
# 748   Given the statutory framework of 18 U.S.C. § 3...       0.050000
# 760   Given the repeal of 18 U.S.C. § 3503 by Pub. L...       0.050000
# 777   Under 18 U.S.C. §§ 2314 and 2315, what evidenc...       0.050000
# 828   Based on the legislative history of 18 U.S.C. ...       0.050000
# 969   What constitutes sufficient evidence of intent...       0.505000
# 1241  Given 18 U.S.C. § 3742(e), what is the standar...       0.050000
# 1261  Given the amendments to 17 U.S.C. § 2319A, par...       0.050000
# 1290  Based on the provided legislative history, par...       0.110662
# 1293  Given the recodification of 18 U.S.C. § 762, n...       0.050000
# 1341  Given the legislative history of the statute i...       0.505000
# 1453  Assuming *arguendo* that a grant of privilege ...       0.050000
# 1465  Given 18 U.S.C. § 201(c) and (d), concerning b...       0.050000
# 1505  Given the panoply of offenses enumerated under...       0.050000
# 1514  In cases involving offenses against minor vict...       0.505000
# 1529  Given the statute of limitations provision cod...       0.050000
# 1638  Under 18 U.S.C. §§ 1581 et seq., what constitu...       0.050000
# 1677  Considering the legislative history provided, ...       0.400000
# 1717  Given the broad discretion afforded to the col...       0.050000
# 1737  Considering the statutory amendments outlined ...       0.050000
# 1741  Given the interplay between 18 U.S.C. §§ 1165 ...       0.050000
# 1769  Given 18 U.S.C. § 3006A, particularly in light...       0.050000
# 1805  Given the amendment history of 18 U.S.C. § XXX...       0.050000
# 1853  Given the mens rea requirement articulated in ...       0.050000
# 1881  Given the legislative history of the provision...       0.050000
# 1893  Assuming a hypothetical fact pattern involving...       0.050000
# 2000  If someone is caught doing something that look...       0.400000
#
#       voyage_weight                                            indices  \
# 4          0.950000  {'sections': {'gemini_top_values': [0.00067709...
# 28         0.950000  {'sections': {'gemini_top_values': [0.00067534...
# 80         0.950000  {'sections': {'gemini_top_values': [0.00068604...
# 144        0.950000  {'sections': {'gemini_top_values': [0.00068233...
# 160        0.950000  {'sections': {'gemini_top_values': [0.00068894...
# 244        0.950000  {'sections': {'gemini_top_values': [0.00067181...
# 289        0.600000  {'sections': {'gemini_top_values': [0.00067417...
# 372        0.950000  {'sections': {'gemini_top_values': [0.00066951...
# 396        0.950000  {'sections': {'gemini_top_values': [0.00068077...
# 404        0.950000  {'sections': {'gemini_top_values': [0.00068116...
# 408        0.950000  {'sections': {'gemini_top_values': [0.00067415...
# 448        0.950000  {'sections': {'gemini_top_values': [0.00067844...
# 460        0.950000  {'sections': {'gemini_top_values': [0.00067567...
# 485        0.600000  {'sections': {'gemini_top_values': [0.00068606...
# 620        0.600000  {'sections': {'gemini_top_values': [0.00067211...
# 644        0.950000  {'sections': {'gemini_top_values': [0.00067553...
# 648        0.950000  {'sections': {'gemini_top_values': [0.00067152...
# 678        0.600000  {'sections': {'gemini_top_values': [0.00067739...
# 724        0.950000  {'sections': {'gemini_top_values': [0.00067258...
# 748        0.950000  {'sections': {'gemini_top_values': [0.00069477...
# 760        0.950000  {'sections': {'gemini_top_values': [0.00068142...
# 777        0.950000  {'sections': {'gemini_top_values': [0.00069645...
# 828        0.950000  {'sections': {'gemini_top_values': [0.00067400...
# 969        0.495000  {'sections': {'gemini_top_values': [0.00068861...
# 1241       0.950000  {'sections': {'gemini_top_values': [0.00068966...
# 1261       0.950000  {'sections': {'gemini_top_values': [0.00066471...
# 1290       0.889338  {'sections': {'gemini_top_values': [0.00069525...
# 1293       0.950000  {'sections': {'gemini_top_values': [0.00067838...
# 1341       0.495000  {'sections': {'gemini_top_values': [0.00069402...
# 1453       0.950000  {'sections': {'gemini_top_values': [0.00068601...
# 1465       0.950000  {'sections': {'gemini_top_values': [0.00067284...
# 1505       0.950000  {'sections': {'gemini_top_values': [0.00068652...
# 1514       0.495000  {'sections': {'gemini_top_values': [0.00069086...
# 1529       0.950000  {'sections': {'gemini_top_values': [0.00068289...
# 1638       0.950000  {'sections': {'gemini_top_values': [0.00065852...
# 1677       0.600000  {'sections': {'gemini_top_values': [0.00069195...
# 1717       0.950000  {'sections': {'gemini_top_values': [0.00067041...
# 1737       0.950000  {'sections': {'gemini_top_values': [0.00069837...
# 1741       0.950000  {'sections': {'gemini_top_values': [0.00070111...
# 1769       0.950000  {'sections': {'gemini_top_values': [0.00069398...
# 1805       0.950000  {'sections': {'gemini_top_values': [0.00066704...
# 1853       0.950000  {'sections': {'gemini_top_values': [0.00068750...
# 1881       0.950000  {'sections': {'gemini_top_values': [0.00069328...
# 1893       0.950000  {'sections': {'gemini_top_values': [0.00067807...
# 2000       0.600000  {'sections': {'gemini_top_values': [0.00070909...
#
#                                                response      time  \
# 4     Based on the provided legal documents, I am un...  2.280774
# 28    Based on the provided legal documents, I am un...  2.053176
# 80    Based on the provided text, I am unable to ans...  2.254357
# 144   Based on the provided text, I am unable to ans...  2.542587
# 160   Based on the provided legal documents, I am un...  3.308697
# 244   I am unable to answer your question. The provi...  1.695283
# 289   I am unable to answer your question. The text ...  1.834677
# 372   I am unable to answer your question. The provi...  2.162959
# 396   Based on the provided legal documents, I am un...  1.937183
# 404   Based on the content provided, I am unable to ...  2.624138
# 408   Based on the provided legal documents, I am un...  2.442273
# 448   Based on the provided legal documents, I am un...  2.174574
# 460   Based on the provided legal documents, I am un...  2.473422
# 485   Based on the provided text, Pub. L. 105-119 am...  2.139584
# 620   Based on the provided legal documents, I am un...  2.192864
# 644   Based on the provided text, I am unable to ans...  2.209826
# 648   Based on the provided legal documents, I am un...  2.558971
# 678   The provided legal documents do not contain in...  1.834725
# 724   Based on the provided legal documents, I am un...  2.063554
# 748   Based on the provided legal documents, I am un...  1.952268
# 760   Based on the provided text, I am unable to ans...  2.748943
# 777   I am unable to answer your question. The provi...  1.858324
# 828   Based on the provided text, I am unable to ans...  2.347085
# 969   Based on the provided legal documents, I am un...  1.987644
# 1241  Based on the provided text, I am unable to ans...  2.185542
# 1261  Based on the provided legal documents, I am un...  2.148175
# 1290  Based on the provided text, I am unable to ans...  1.880923
# 1293  Based on the provided text, I am unable to ans...  2.289939
# 1341  Based on the provided legal documents, I am un...  2.461209
# 1453  Based on the provided legal documents, I am un...  2.198667
# 1465  Based on the provided text, I am unable to ans...  2.082510
# 1505  Based on the provided text, I am unable to ans...  2.040328
# 1514  The provided legal documents do not contain th...  1.837319
# 1529  Based on the provided legal documents, I am un...  2.404796
# 1638  Based on the provided legal documents, I am un...  1.970090
# 1677  Based on the provided text, I am unable to ans...  1.813803
# 1717  Based on the provided text, I am unable to ans...  2.054915
# 1737  Based on the provided text, I am unable to ans...  2.377328
# 1741  Based on the provided legal documents, I am un...  2.935817
# 1769  Based on the provided legal documents, I am un...  4.130874
# 1805  Based on the provided text, I am unable to ans...  2.617318
# 1853  Based on the provided text, I am unable to ans...  2.452986
# 1881  I am sorry, but I cannot provide an answer to ...  2.761182
# 1893  Based on the provided legal documents, I am un...  2.765249
# 2000  I am unable to answer your question. The docum...  1.853323
#
#                                          indices_parsed  \
# 4     {'sections': {'gemini_top_values': [0.00067709...
# 28    {'sections': {'gemini_top_values': [0.00067534...
# 80    {'sections': {'gemini_top_values': [0.00068604...
# 144   {'sections': {'gemini_top_values': [0.00068233...
# 160   {'sections': {'gemini_top_values': [0.00068894...
# 244   {'sections': {'gemini_top_values': [0.00067181...
# 289   {'sections': {'gemini_top_values': [0.00067417...
# 372   {'sections': {'gemini_top_values': [0.00066951...
# 396   {'sections': {'gemini_top_values': [0.00068077...
# 404   {'sections': {'gemini_top_values': [0.00068116...
# 408   {'sections': {'gemini_top_values': [0.00067415...
# 448   {'sections': {'gemini_top_values': [0.00067844...
# 460   {'sections': {'gemini_top_values': [0.00067567...
# 485   {'sections': {'gemini_top_values': [0.00068606...
# 620   {'sections': {'gemini_top_values': [0.00067211...
# 644   {'sections': {'gemini_top_values': [0.00067553...
# 648   {'sections': {'gemini_top_values': [0.00067152...
# 678   {'sections': {'gemini_top_values': [0.00067739...
# 724   {'sections': {'gemini_top_values': [0.00067258...
# 748   {'sections': {'gemini_top_values': [0.00069477...
# 760   {'sections': {'gemini_top_values': [0.00068142...
# 777   {'sections': {'gemini_top_values': [0.00069645...
# 828   {'sections': {'gemini_top_values': [0.00067400...
# 969   {'sections': {'gemini_top_values': [0.00068861...
# 1241  {'sections': {'gemini_top_values': [0.00068966...
# 1261  {'sections': {'gemini_top_values': [0.00066471...
# 1290  {'sections': {'gemini_top_values': [0.00069525...
# 1293  {'sections': {'gemini_top_values': [0.00067838...
# 1341  {'sections': {'gemini_top_values': [0.00069402...
# 1453  {'sections': {'gemini_top_values': [0.00068601...
# 1465  {'sections': {'gemini_top_values': [0.00067284...
# 1505  {'sections': {'gemini_top_values': [0.00068652...
# 1514  {'sections': {'gemini_top_values': [0.00069086...
# 1529  {'sections': {'gemini_top_values': [0.00068289...
# 1638  {'sections': {'gemini_top_values': [0.00065852...
# 1677  {'sections': {'gemini_top_values': [0.00069195...
# 1717  {'sections': {'gemini_top_values': [0.00067041...
# 1737  {'sections': {'gemini_top_values': [0.00069837...
# 1741  {'sections': {'gemini_top_values': [0.00070111...
# 1769  {'sections': {'gemini_top_values': [0.00069398...
# 1805  {'sections': {'gemini_top_values': [0.00066704...
# 1853  {'sections': {'gemini_top_values': [0.00068750...
# 1881  {'sections': {'gemini_top_values': [0.00069328...
# 1893  {'sections': {'gemini_top_values': [0.00067807...
# 2000  {'sections': {'gemini_top_values': [0.00070909...
#
#                                       gemini_top_values  gemini_top_avg  \
# 4                               [0.0006770953186787665]        0.000677
# 28                              [0.0006753462948836386]        0.000675
# 80                              [0.0006860459689050913]        0.000686
# 144                             [0.0006823342409916222]        0.000682
# 160                             [0.0006889401702210307]        0.000689
# 244                             [0.0006718133226968348]        0.000672
# 289                             [0.0006741703837178648]        0.000674
# 372                             [0.0006695115007460117]        0.000670
# 396                             [0.0006807736936025321]        0.000681
# 404                             [0.0006811612984165549]        0.000681
# 408                             [0.0006741551915183663]        0.000674
# 448                             [0.0006784498109482229]        0.000678
# 460                             [0.0006756793009117246]        0.000676
# 485   [0.0006860623834654689, 0.0006810761988162994,...        0.000680
# 620   [0.0006721186800859869, 0.0006708565051667392,...        0.000671
# 644                              [0.000675537739880383]        0.000676
# 648                              [0.000671528687234968]        0.000672
# 678   [0.0006773959030397236, 0.0006726000574417412,...        0.000674
# 724                             [0.0006725816638208926]        0.000673
# 748                             [0.0006947794463485479]        0.000695
# 760                              [0.000681422941852361]        0.000681
# 777                             [0.0006964546046219766]        0.000696
# 828                             [0.0006740066455677152]        0.000674
# 969   [0.000688613043166697, 0.0006810550694353878, ...        0.000683
# 1241                            [0.0006896666018292308]        0.000690
# 1261                            [0.0006647143745794892]        0.000665
# 1290                            [0.0006952579715289176]        0.000695
# 1293                            [0.0006783825810998678]        0.000678
# 1341  [0.000694025366101414, 0.0006828118930570781, ...        0.000684
# 1453                            [0.0006860124412924051]        0.000686
# 1465                            [0.0006728414446115494]        0.000673
# 1505                            [0.0006865215254947543]        0.000687
# 1514  [0.0006908682407811284, 0.0006898116553202271,...        0.000687
# 1529                            [0.0006828963523730636]        0.000683
# 1638                             [0.000658522651065141]        0.000659
# 1677     [0.0006919503211975098, 0.0006856417167000473]        0.000689
# 1717                            [0.0006704151164740324]        0.000670
# 1737                            [0.0006983741768635809]        0.000698
# 1741                            [0.0007011146517470479]        0.000701
# 1769                            [0.0006939852610230446]        0.000694
# 1805                            [0.0006670455331914127]        0.000667
# 1853                            [0.0006875071558170021]        0.000688
# 1881                            [0.0006932886317372322]        0.000693
# 1893                            [0.0006780718686059117]        0.000678
# 2000                            [0.0007090988219715655]        0.000709
#
#       query_length  response_length  weight_ratio  time_winsorized
# 4             1022              455      0.052632         2.280774
# 28             990              396      0.052632         2.053176
# 80            1001              353      0.052632         2.254357
# 144           1059              888      0.052632         2.542587
# 160           1076             1276      0.052632         3.308697
# 244            675              269      0.052632         1.695283
# 289            661              418      0.666667         1.834677
# 372            839              243      0.052632         2.162959
# 396            970              301      0.052632         1.937183
# 404           1065              612      0.052632         2.624138
# 408            954              558      0.052632         2.442273
# 448            846              528      0.052632         2.174574
# 460           1019              437      0.052632         2.473422
# 485            601              513      0.666667         2.139584
# 620            775              383      0.666667         2.192864
# 644            865              371      0.052632         2.209826
# 648           1173              547      0.052632         2.558971
# 678            660              337      0.666667         1.834725
# 724           1071              426      0.052632         2.063554
# 748           1072              538      0.052632         1.952268
# 760           1080             1065      0.052632         2.748943
# 777            630              333      0.052632         1.858324
# 828           1099              619      0.052632         2.347085
# 969            619              331      1.020202         1.987644
# 1241           912              556      0.052632         2.185542
# 1261           795              656      0.052632         2.148175
# 1290           601              133      0.124432         1.880923
# 1293           882              754      0.052632         2.289939
# 1341           832              596      1.020202         2.461209
# 1453           922              567      0.052632         2.198667
# 1465          1132              455      0.052632         2.082510
# 1505          1368              486      0.052632         2.040328
# 1514           524              509      1.020202         1.837319
# 1529          1221              515      0.052632         2.404796
# 1638           675              312      0.052632         1.970090
# 1677           953              153      0.666667         1.813803
# 1717           967              236      0.052632         2.054915
# 1737          1347              580      0.052632         2.377328
# 1741          1292              919      0.052632         2.935817
# 1769          1015              538      0.052632         4.130874
# 1805           961              427      0.052632         2.617318
# 1853           975              414      0.052632         2.452986
# 1881           820              330      0.052632         2.761182
# 1893          1212              844      0.052632         2.765249
# 2000           325              236      0.666667         1.853323

# %%
filtered_df['response_length']
# Out:
# 4        455
# 28       396
# 80       353
# 144      888
# 160     1276
# 244      269
# 289      418
# 372      243
# 396      301
# 404      612
# 408      558
# 448      528
# 460      437
# 485      513
# 620      383
# 644      371
# 648      547
# 678      337
# 724      426
# 748      538
# 760     1065
# 777      333
# 828      619
# 969      331
# 1241     556
# 1261     656
# 1290     133
# 1293     754
# 1341     596
# 1453     567
# 1465     455
# 1505     486
# 1514     509
# 1529     515
# 1638     312
# 1677     153
# 1717     236
# 1737     580
# 1741     919
# 1769     538
# 1805     427
# 1853     414
# 1881     330
# 1893     844
# 2000     236
# Name: response_length, dtype: int64

# %%
filtered_df['response']
# Out:
# 4       Based on the provided legal documents, I am un...
# 28      Based on the provided legal documents, I am un...
# 80      Based on the provided text, I am unable to ans...
# 144     Based on the provided text, I am unable to ans...
# 160     Based on the provided legal documents, I am un...
# 244     I am unable to answer your question. The provi...
# 289     I am unable to answer your question. The text ...
# 372     I am unable to answer your question. The provi...
# 396     Based on the provided legal documents, I am un...
# 404     Based on the content provided, I am unable to ...
# 408     Based on the provided legal documents, I am un...
# 448     Based on the provided legal documents, I am un...
# 460     Based on the provided legal documents, I am un...
# 485     Based on the provided text, Pub. L. 105-119 am...
# 620     Based on the provided legal documents, I am un...
# 644     Based on the provided text, I am unable to ans...
# 648     Based on the provided legal documents, I am un...
# 678     The provided legal documents do not contain in...
# 724     Based on the provided legal documents, I am un...
# 748     Based on the provided legal documents, I am un...
# 760     Based on the provided text, I am unable to ans...
# 777     I am unable to answer your question. The provi...
# 828     Based on the provided text, I am unable to ans...
# 969     Based on the provided legal documents, I am un...
# 1241    Based on the provided text, I am unable to ans...
# 1261    Based on the provided legal documents, I am un...
# 1290    Based on the provided text, I am unable to ans...
# 1293    Based on the provided text, I am unable to ans...
# 1341    Based on the provided legal documents, I am un...
# 1453    Based on the provided legal documents, I am un...
# 1465    Based on the provided text, I am unable to ans...
# 1505    Based on the provided text, I am unable to ans...
# 1514    The provided legal documents do not contain th...
# 1529    Based on the provided legal documents, I am un...
# 1638    Based on the provided legal documents, I am un...
# 1677    Based on the provided text, I am unable to ans...
# 1717    Based on the provided text, I am unable to ans...
# 1737    Based on the provided text, I am unable to ans...
# 1741    Based on the provided legal documents, I am un...
# 1769    Based on the provided legal documents, I am un...
# 1805    Based on the provided text, I am unable to ans...
# 1853    Based on the provided text, I am unable to ans...
# 1881    I am sorry, but I cannot provide an answer to ...
# 1893    Based on the provided legal documents, I am un...
# 2000    I am unable to answer your question. The docum...
# Name: response, dtype: object

# %%
filtered_df.shape
# Out:
# (45, 13)
